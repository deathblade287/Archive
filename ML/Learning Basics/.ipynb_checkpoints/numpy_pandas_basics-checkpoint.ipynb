# %%
# June 04th 2021

# %%
import numpy as np

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
a.shape
# Out:
# (3,)

# %%
b = np.array((1,2,3))
print(type(b))
print(b.shape)
print(b)
# Out:
# <class 'numpy.ndarray'>
# (3,)
# [1 2 3]

# %%
c = np.array([ [1,2,3] , [6,7,8] ])
print(c.shape)
print("\n")
print(c)
# Out:
# (2, 3)
#
#
# [[1 2 3]
#  [6 7 8]]

# %%
d = np.array([ [[1,2,3] , [3,4,5] , [5,6,7]]  ,  [[6,6,6] , [7,7,7] , [8,8,8]] ])
print(d)
print(d.shape)
sh = d.shape
print("The type of Sh variable is", type(sh))
print(len(sh))
# Out:
# [[[1 2 3]
#   [3 4 5]
#   [5 6 7]]
#
#  [[6 6 6]
#   [7 7 7]
#   [8 8 8]]]
# (2, 3, 3)
# The type of Sh variable is <class 'tuple'>
# 3

# %%
d[1,0,0]
# first index is for the first dimension and refers to the matrix
# second index refers the row
# third index refers the col
# Out:
# 6

# %%
d[0,2,0]
# Out:
# 5

# %%
d[1,0,0]
# Out:
# 6

# %%
#np.arange(start, end , interval)
rng = np.arange(10.5,51.5,5)
print(rng)

# arange helps to create single dimensional array with intervals of specified value
# Out:
# [10.5 15.5 20.5 25.5 30.5 35.5 40.5 45.5 50.5]

# %%
lin = np.linspace(13,15,50)
print(lin)

# arange helps to create single dimensional array with specified numberes required with linear space/gap
# Out:
# [13.         13.04081633 13.08163265 13.12244898 13.16326531 13.20408163
#  13.24489796 13.28571429 13.32653061 13.36734694 13.40816327 13.44897959
#  13.48979592 13.53061224 13.57142857 13.6122449  13.65306122 13.69387755
#  13.73469388 13.7755102  13.81632653 13.85714286 13.89795918 13.93877551
#  13.97959184 14.02040816 14.06122449 14.10204082 14.14285714 14.18367347
#  14.2244898  14.26530612 14.30612245 14.34693878 14.3877551  14.42857143
#  14.46938776 14.51020408 14.55102041 14.59183673 14.63265306 14.67346939
#  14.71428571 14.75510204 14.79591837 14.83673469 14.87755102 14.91836735
#  14.95918367 15.        ]

# %%
import pandas as pd
import os

# %%
# pandas is a well renowned library used for data transformation within Machine Learning

# %%
os.chdir(r"/home/deathblade287/Dropbox/ML")
df = pd.read_csv("insurance-premium.csv")

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
premiumvar = df['age'][0:]
# premiumvar
print(premiumvar)
print(type(premiumvar))
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
v = premiumvar.to_list()
print(v)
print(type(v))
# Out:
# [19, 18, 28, 33, 32, 31, 46, 37, 37, 60, 25, 62, 23, 56, 27, 19, 52, 23, 56, 30, 60, 30, 18, 34, 37, 59, 63, 55, 23, 31, 22, 18, 19, 63, 28, 19, 62, 26, 35, 60, 24, 31, 41, 37, 38, 55, 18, 28, 60, 36, 18, 21, 48, 36, 40, 58, 58, 18, 53, 34, 43, 25, 64, 28, 20, 19, 61, 40, 40, 28, 27, 31, 53, 58, 44, 57, 29, 21, 22, 41, 31, 45, 22, 48, 37, 45, 57, 56, 46, 55, 21, 53, 59, 35, 64, 28, 54, 55, 56, 38, 41, 30, 18, 61, 34, 20, 19, 26, 29, 63, 54, 55, 37, 21, 52, 60, 58, 29, 49, 37, 44, 18, 20, 44, 47, 26, 19, 52, 32, 38, 59, 61, 53, 19, 20, 22, 19, 22, 54, 22, 34, 26, 34, 29, 30, 29, 46, 51, 53, 19, 35, 48, 32, 42, 40, 44, 48, 18, 30, 50, 42, 18, 54, 32, 37, 47, 20, 32, 19, 27, 63, 49, 18, 35, 24, 63, 38, 54, 46, 41, 58, 18, 22, 44, 44, 36, 26, 30, 41, 29, 61, 36, 25, 56, 18, 19, 39, 45, 51, 64, 19, 48, 60, 27, 46, 28, 59, 35, 63, 40, 20, 40, 24, 34, 45, 41, 53, 27, 26, 24, 34, 53, 32, 19, 42, 55, 28, 58, 41, 47, 42, 59, 19, 59, 39, 40, 18, 31, 19, 44, 23, 33, 55, 40, 63, 54, 60, 24, 19, 2
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
# how to get data from sql server
import pyodbc
server = 'DESKTOP-EOUJV2S\SQLEXPRESS'
dbname = 'iplteams'
cn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server}; SERVER= ' + server + ';DATABASE='+ dbname + ' ;Trusted_Connection=yes;')
crsr = cn.cursor()

qry='select * from players'

query = pd.read_sql_query(qry,cn)

df = pd.DataFrame(query,columns=['Name','Age','Matches','Country'])

print(df)
cn.close()
# Out:
#         Name  Age  Matches       Country
# 0        ABD   33      108  South Africa
# 1    Ajinkya   29       55         India
# 2     Bumrah   27       50         India
# 3   Ferguson   29       30            NZ
# 4      Ishan   20       22         India
# 5       Jack   20       40        Canada
# 6      Rohit   34       15         India
# 7    Rohit S   33       95         India
# 8    Shikhar   33      102         India
# 9      Surya   29       77         India
# 10     Virat   32      100         India
# 11    ViratK   32      101         India
# 12    Warner   34      120     Australia

# %%
r = np.random.rand(2,3)
print(r)
# Out:
# [[0.50572275 0.55718592 0.65883529]
#  [0.57141789 0.74645339 0.37690693]]

# %%
r_int = np.random.randint(10,20,size = (3,4,5))
print(r_int)
# Out:
# [[[11 18 18 10 18]
#   [10 13 15 18 13]
#   [10 11 10 10 11]
#   [10 19 15 19 19]]
#
#  [[17 16 12 18 14]
#   [17 16 12 12 14]
#   [13 13 17 12 18]
#   [12 14 18 17 12]]
#
#  [[18 15 18 14 10]
#   [18 13 19 17 10]
#   [15 16 13 18 10]
#   [15 14 14 14 14]]]

# %%
a = np.array([[1,2,3] , [5,6,7]])
b = np.array([[3,4,5] , [7,7,7]])
c = a*b
print(c)

# * refers to scalar multiplication
# Out:
# [[ 3  8 15]
#  [35 42 49]]

# %%
a = np.array([[1,2,3] , [5,6,7]])
b = np.array([[3,4] , [7,7] , [8,8]])
c = np.matmul(a,b)
print(c)

# the col of the first matrix should match the row of the second matrix
# Out:
# [[ 41  42]
#  [113 118]]

# %%
a = np.array([[1,2,3] , [5,6,7]])
b = np.array([[3,4] , [7,7] , [8,8]])
c = np.dot(a,b)
print(c)
# Out:
# [[ 41  42]
#  [113 118]]

# %%
# Assignment # 1
# Create a 4 dimensional array and experiment to access various different values

# Assignment # 2
# Download "medical insurance claim fraud.csv" from kaggle.com
# Create DataFrame from this downloaded csv

# Assignment # 3
# Create DataFrame from any of your existing SQL Server table

# %%
# June 11th 2021

# %%
# https://www.kaggle.com/buntyshah/auto-insurance-claims-data?select=insurance_claims.csv

# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\Students\Machine Learning\insurance_claims.csv")

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
pd.set_option("display.max_columns",40)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
pd.set_option("display.max_rows",10)
# this is to set the limit of visible rows and columns else it will show 10 first cols and 10 last cols
# Similarly with rows, it will show first 5 rows and then last 5 rows

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# 5                   256   39         104594       2006-10-12           OH
# 6                   137   34         413978       2000-06-04           IN
# 7                   165   37         429027       1990-02-03           IL
# 8                    27   33         485665       1997-02-05           IL
# 9                   212   42         636550       2011-07-25           IL
# 10                  235   42         543610       2002-05-26           OH
# 11                  447   61         214618       1999-05-29           OH
# ...

# %%
df.head(20)
# Out:
#     months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                  328   48         521585       2014-10-17           OH
# 1                  228   42         342868       2006-06-27           IN
# 2                  134   29         687698       2000-09-06           OH
# 3                  256   41         227811       1990-05-25           IL
# 4                  228   44         367455       2014-06-06           IL
# 5                  256   39         104594       2006-10-12           OH
# 6                  137   34         413978       2000-06-04           IN
# 7                  165   37         429027       1990-02-03           IL
# 8                   27   33         485665       1997-02-05           IL
# 9                  212   42         636550       2011-07-25           IL
# 10                 235   42         543610       2002-05-26           OH
# 11                 447   61         214618       1999-05-29           OH
# ...

# %%
df.tail(10)
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 990                 286   43         663190       1994-02-05           IL
# 991                 257   44         109392       2006-07-12           OH
# 992                  94   26         215278       2007-10-24           IN
# 993                 124   28         674570       2001-12-08           OH
# 994                 141   30         681486       2007-03-24           IN
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 990    100/300                500                1564.43         3000000
# ...

# %%
l = [1,2,3,4,5,[10,20,30]]
l[5][0]
# this is how we index list
# Out:
# 10

# %%
df["age"]
# Out:
# 0      48
# 1      42
# 2      29
# 3      41
# 4      44
#        ..
# 995    38
# 996    41
# 997    34
# 998    62
# 999    60
# Name: age, Length: 1000, dtype: int64

# %%
df[["age","policy_state"]]
# Out:
#      age policy_state
# 0     48           OH
# 1     42           IN
# 2     29           OH
# 3     41           IL
# 4     44           IL
# ..   ...          ...
# 995   38           OH
# 996   41           IL
# 997   34           OH
# 998   62           IL
# 999   60           OH
#
# [1000 rows x 2 columns]

# %%
# .loc stands for location
# it takes 2 arguments as rows and cols
df.loc[2,"policy_state"]
# Out:
# 'OH'

# %%
df.loc[0:10 , "age":"umbrella_limit"]
# Out:
#     age  policy_number policy_bind_date policy_state policy_csl  \
# 0    48         521585       2014-10-17           OH    250/500
# 1    42         342868       2006-06-27           IN    250/500
# 2    29         687698       2000-09-06           OH    100/300
# 3    41         227811       1990-05-25           IL    250/500
# 4    44         367455       2014-06-06           IL   500/1000
# ..  ...            ...              ...          ...        ...
# 6    34         413978       2000-06-04           IN    250/500
# 7    37         429027       1990-02-03           IL    100/300
# 8    33         485665       1997-02-05           IL    100/300
# 9    42         636550       2011-07-25           IL    100/300
# 10   42         543610       2002-05-26           OH    100/300
#
#     policy_deductable  policy_annual_premium  umbrella_limit
# 0                1000                1406.91               0
# 1                2000                1197.22         5000000
# ...

# %%
df.loc[[0,2,10] , ["age","policy_state" , "umbrella_limit"]]
# we can use multiple cols or multiple rows and passed as list or tuples
# Out:
#     age policy_state  umbrella_limit
# 0    48           OH               0
# 2    29           OH         5000000
# 10   42           OH         4000000

# %%
df.loc[(0,2,10) , ("age" , "policy_state" , "umbrella_limit")]
# Out:
#     age policy_state  umbrella_limit
# 0    48           OH               0
# 2    29           OH         5000000
# 10   42           OH         4000000

# %%
# iloc stands for integer location
# iloc will take integer values as arguments
df.iloc[0]
# Out:
# months_as_customer           328
# age                           48
# policy_number             521585
# policy_bind_date      2014-10-17
# policy_state                  OH
#                          ...
# auto_make                   Saab
# auto_model                   92x
# auto_year                   2004
# fraud_reported                 Y
# _c39                         NaN
# Name: 0, Length: 40, dtype: object

# %%
df.iloc[0,2]
# Out:
# 521585

# %%
df.iloc[[0,2,5] , [4,5,7]]
# Out:
#   policy_state policy_csl  policy_annual_premium
# 0           OH    250/500                1406.91
# 2           OH    100/300                1413.14
# 5           OH    250/500                1351.10

# %%
d =  {"name":"Ricky" , "country":"Australia" , "runs":12000}

# %%
df_from_dict = pd.DataFrame([d])

# %%
df_from_dict
# Out:
#     name    country   runs
# 0  Ricky  Australia  12000

# %%
# how to use filters or conditions within DataFrame/Pandas
age_filter = df["age"]>40
df[age_filter]
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# 9                   212   42         636550       2011-07-25           IL
# ..                  ...  ...            ...              ...          ...
# 990                 286   43         663190       1994-02-05           IL
# 991                 257   44         109392       2006-07-12           OH
# 996                 285   41         186934       2014-01-05           IL
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
# we will look into changing indexes later

# %%
age_filter
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997    False
# 998     True
# 999     True
# Name: age, Length: 1000, dtype: bool

# %%
age_premium_filter = (df["age"] > 40) & (df["policy_annual_premium"] < 1200)
df[age_premium_filter]
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 1                   228   42         342868       2006-06-27           IN
# 11                  447   61         214618       1999-05-29           OH
# 15                  473   58         892874       1992-10-19           IN
# 20                  460   62         183430       2002-06-25           IN
# 21                  217   41         431876       2005-11-27           IL
# ..                  ...  ...            ...              ...          ...
# 977                 266   42         929306       2003-03-06           IN
# 981                  50   44         525862       2000-10-18           OH
# 982                 230   43         490514       2007-02-09           IN
# 986                 232   42         182953       2013-04-30           IN
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df[~age_premium_filter]
# ~ mean opposite of filter applied
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# 5                   256   39         104594       2006-10-12           OH
# ..                  ...  ...            ...              ...          ...
# 994                 141   30         681486       2007-03-24           IN
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
age_premium_filter = (df["age"] > 40) | (df["policy_annual_premium"] < 1200)
df[age_premium_filter]
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# 7                   165   37         429027       1990-02-03           IL
# ..                  ...  ...            ...              ...          ...
# 991                 257   44         109392       2006-07-12           OH
# 992                  94   26         215278       2007-10-24           IN
# 996                 285   41         186934       2014-01-05           IL
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
age_premium_filter
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Length: 1000, dtype: bool

# %%
# Assignment # 1
# Create a Pandas DataFrame from Numpy array which you have created in earlier assignment

# Assignment # 2
# Study and reasearch online for the difference between .loc and .iloc

# Assignment # 3
# Practice multiple conditions on the dataset which you have downloaded - with and , or , ~

# %%
June 18th 2021

# %%
students = {'name':['A','B','C','D','E'], 'Age':[13,14,12,15,14] , 'Address':["Delhi","Gurugram","Noida","Delhi","Noida"]}

# %%
students
# Out:
# {'name': ['A', 'B', 'C', 'D', 'E'],
#  'Age': [13, 14, 12, 15, 14],
#  'Address': ['Delhi', 'Gurugram', 'Noida', 'Delhi', 'Noida']}

# %%
df_student = pd.DataFrame(students)

# %%
df_student
# Out:
#   name  Age   Address
# 0    A   13     Delhi
# 1    B   14  Gurugram
# 2    C   12     Noida
# 3    D   15     Delhi
# 4    E   14     Noida

# %%
df_claims = pd.read_csv("insurance_claims.csv")

# %%
df_claims
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# 5                   256   39         104594       2006-10-12           OH
# 6                   137   34         413978       2000-06-04           IN
# 7                   165   37         429027       1990-02-03           IL
# 8                    27   33         485665       1997-02-05           IL
# 9                   212   42         636550       2011-07-25           IL
# 10                  235   42         543610       2002-05-26           OH
# 11                  447   61         214618       1999-05-29           OH
# ...

# %%
pd.set_option("display.max_rows",40)

# %%
df_claims.loc[0:5 , "age":"policy_csl"]
# Out:
#    age  policy_number policy_bind_date policy_state policy_csl
# 0   48         521585       2014-10-17           OH    250/500
# 1   42         342868       2006-06-27           IN    250/500
# 2   29         687698       2000-09-06           OH    100/300
# 3   41         227811       1990-05-25           IL    250/500
# 4   44         367455       2014-06-06           IL   500/1000
# 5   39         104594       2006-10-12           OH    250/500

# %%
df_claims.iloc[0:5 , 2:6]
# Out:
#    policy_number policy_bind_date policy_state policy_csl
# 0         521585       2014-10-17           OH    250/500
# 1         342868       2006-06-27           IN    250/500
# 2         687698       2000-09-06           OH    100/300
# 3         227811       1990-05-25           IL    250/500
# 4         367455       2014-06-06           IL   500/1000

# %%
df_claims.iloc[[1,3,5,7] , [2,4,6,8]]
# Out:
#    policy_number policy_state  policy_deductable  umbrella_limit
# 1         342868           IN               2000         5000000
# 3         227811           IL               2000         6000000
# 5         104594           OH               1000               0
# 7         429027           IL               1000               0

# %%
df_claims.loc[[1,3,5,7] , ["age","policy_state"]]
# Out:
#    age policy_state
# 1   42           IN
# 3   41           IL
# 5   39           OH
# 7   37           IL

# %%
df_claims.iloc[[1,3,5,7] , ["age","policy_state"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-b0f695b69ef3> in <module>
# ----> 1 df_claims.iloc[[1,3,5,7] , ["age","policy_state"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2141     def _getitem_tuple(self, tup):
#    2142
# -> 2143         self._has_valid_tuple(tup)
#    2144         try:
#    2145             return self._getitem_lowerdim(tup)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
# ...

# %%
# .loc works with integers as rows since default indexes of rows are integers
# .loc requires strings as cols since default indexes of cols are strings
# .iloc requires integers as rows and cols
# both .loc and .iloc can work with range of rows and cols
# when working with range within .loc, it includes the last row or col mentioned withn the range
# however it doesnt when workng with .iloc

# try with float indexes

# %%
# How to update a row value with a specific col
df_student
# Out:
#   name  Age   Address
# 0    A   13     Delhi
# 1    B   14  Gurugram
# 2    C   12     Noida
# 3    D   15     Delhi
# 4    E   14     Noida

# %%
df_student.loc[2,["name"]]=["Z"]
df_student

# dataframe.loc[row no,["colname"]] = ["value"]
# Out:
#   name  Age   Address
# 0    A   13     Delhi
# 1    B   14  Gurugram
# 2    Z   12     Noida
# 3    D   15     Delhi
# 4    E   14     Noida

# %%
df_student.iloc[2,[0]]=["C"]

# %%
df_student
# Out:
#   name Age   Address
# 0    A  13     Delhi
# 1    B  14  Gurugram
# 2    C   C     Noida
# 3    D  15     Delhi
# 4    E  14     Noida

# %%
df_student.iloc[2,1]=["C"]

# %%
df_student.iloc[2:4,0]=["C"]

# %%
df_student
# Out:
#   name Age   Address
# 0    A  13     Delhi
# 1    B  14  Gurugram
# 2    C   C     Noida
# 3    C  15     Delhi
# 4    E  14     Noida

# %%
df_student.loc[2:5,"name":"Address"]=["Z"]

# %%
df_student
# Out:
#   name Age   Address
# 0    A  13     Delhi
# 1    B  14  Gurugram
# 2    Z   Z         Z
# 3    Z   Z         Z
# 4    Z   Z         Z

# %%
df_student
# Out:
#   name  Age   Address
# 0    A   13     Delhi
# 1    B   14  Gurugram
# 2    C   12     Noida
# 3    D   15     Delhi
# 4    E   14     Noida

# %%
# If we have to change a col value but on specific condition

# %%
if df_student.loc["Address"]=="Noida":
    df["Name"] = "N"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Address'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-4f314e6aa222> in <module>
# ----> 1 if df_student.loc["Address"]=="Noida":
#       2     df["Name"] = "N"
#
# ...

# %%
filter_stud = df_student["Address"]=="Noida"
# created a filter

# %%
df_student.loc[filter_stud,0] = "N"
# since we have used .loc, it expected string as colname
# we gave 0 and since there was no col name as "0", it created a new col

# %%
df_student.loc[filter_stud,"name"] = "N"
# here, we gave the col name as string and it updated the provided colname with the filter

# %%
df_student
# Out:
#   name  Age   Address
# 0    A   13     Delhi
# 1    B   14  Gurugram
# 2    C   12     Noida
# 3    D   15     Delhi
# 4    E   14     Noida

# %%
df_student.loc[filter_stud,["name","Age"]]
# Out:
#   name  Age
# 2    N   12
# 4    N   14

# %%
filter_stud_age = df_student["Address"] == "Noida"
df_student.loc[filter_stud_age , "Age"] = 19
df_student
# Out:
#   name  Age   Address
# 0    A   13     Delhi
# 1    B   14  Gurugram
# 2    C   19     Noida
# 3    D   15     Delhi
# 4    E   19     Noida

# %%
# Lets put this on hold for today and we will continue Pandas in next class
