# %%
# !pip install sklearn
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import os
from utils import label_encoder_auto, auto_dropper

# %%
data, columns_encoded = label_encoder_auto("orignal_data.csv")

# %%
data
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        1       1     46      1     93      1      1        14         2
# 1        2       1     82      0     79      1      2        74         2
# 2        3       1     42      0     51      0      0        27         0
# 3        4       1     22      0     14      0      2         3         2
# 4        5       1     98      0     70      0      1        65         0
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    211       1     85      1     84      1      1        76         0
# 211    212       1     25      1     24      1      2        60         2
# 212    213       1     46      1     49      1      1        64         0
# 213    214       0     64      1     45      1      1        14         0
# 214    215       1     36      0     21      1      2         4         0
#
#      workex  etest_p  specialisation  mba_p  status  salary
# ...

# %%
columns_encoded
# Out:
# ['gender',
#  'ssc_p',
#  'ssc_b',
#  'hsc_p',
#  'hsc_b',
#  'hsc_s',
#  'degree_p',
#  'degree_t',
#  'workex',
#  'etest_p',
#  'specialisation',
#  'mba_p',
#  'status',
#  'salary']

# %%
data = data.drop("salary",axis=1) # I dont know how to create model with 2 y's

# %%
y = data["status"]
data = data.drop("status",axis=1)

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 210    1
# 211    1
# 212    1
# 213    1
# 214    0
# Name: status, Length: 215, dtype: int64

# %%
auto_dropper(data, y)
# Out:
# ()
# ('sl_no',)
# ('gender',)
# ('ssc_p',)
# ('ssc_b',)
# ('hsc_p',)
# ('hsc_b',)
# ('hsc_s',)
# ('degree_p',)
# ('degree_t',)
# ('workex',)
# ('etest_p',)
# ('specialisation',)
# ('mba_p',)
# ('sl_no', 'gender')
# ('sl_no', 'ssc_p')
# ('sl_no', 'ssc_b')
# ('sl_no', 'hsc_p')
# ('sl_no', 'hsc_b')
# ('sl_no', 'hsc_s')
# ('sl_no', 'degree_p')
# ('sl_no', 'degree_t')
# ('sl_no', 'workex')
# ('sl_no', 'etest_p')
# ('sl_no', 'specialisation')
# ('sl_no', 'mba_p')
# ('gender', 'ssc_p')
# ('gender', 'ssc_b')
# ('gender', 'hsc_p')
# ('gender', 'hsc_b')
# ('gender', 'hsc_s')
# ('gender', 'degree_p')
# ('gender', 'degree_t')
# ('gender', 'workex')
# ('gender', 'etest_p')
# ('gender', 'specialisation')
# ('gender', 'mba_p')
# ('ssc_p', 'ssc_b')
# ('ssc_p', 'hsc_p')
# ('ssc_p', 'hsc_b')
# ('ssc_p', 'hsc_s')
# ('ssc_p', 'degree_p')
# ('ssc_p', 'degree_t')
# ('ssc_p', 'workex')
# ('ssc_p', 'etest_p')
# ('ssc_p', 'specialisation')
# ('ssc_p', 'mba_p')
# ('ssc_b', 'hsc_p')
# ('ssc_b', 'hsc_b')
# ...

# %%
print(len(data.columns))
data.columns

# %%
sc = StandardScaler()
data = sc.fit_transform(data)

# %%
data

# %%
# Dividing Data Into Training & Test For Model
seed = 9
test_size = 0.3
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=test_size, random_state=seed)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression(normalize=True)
type(X_test)

# %%
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
# Accuracy Of Model
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
